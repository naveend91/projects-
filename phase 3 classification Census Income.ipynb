# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
#basic sanity of date
df.shape#number of rowa and columns
# Out:
# (32560, 15)

# %%
#cheking top 15 head of data to see distribution--in countryes a swmbol '?'seen 
df.head(15)
# Out:
#     Age          Workclass  Fnlwgt      Education  Education_num  \
# 0    50   Self-emp-not-inc   83311      Bachelors             13
# 1    38            Private  215646        HS-grad              9
# 2    53            Private  234721           11th              7
# 3    28            Private  338409      Bachelors             13
# 4    37            Private  284582        Masters             14
# 5    49            Private  160187            9th              5
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
# 11   23            Private  122272      Bachelors             13
# 12   32            Private  205019     Assoc-acdm             12
# ...

# %%
df.tail(16)
# Out:
#        Age          Workclass  Fnlwgt      Education  Education_num  \
# 32544   39          Local-gov  111499     Assoc-acdm             12
# 32545   37            Private  198216     Assoc-acdm             12
# 32546   43            Private  260761        HS-grad              9
# 32547   65   Self-emp-not-inc   99359    Prof-school             15
# 32548   43          State-gov  255835   Some-college             10
# 32549   43   Self-emp-not-inc   27242   Some-college             10
# 32550   32            Private   34066           10th              6
# 32551   43            Private   84661      Assoc-voc             11
# 32552   32            Private  116138        Masters             14
# 32553   53            Private  321865        Masters             14
# 32554   22            Private  310152   Some-college             10
# 32555   27            Private  257302     Assoc-acdm             12
# 32556   40            Private  154374        HS-grad              9
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
#cheking null values()--no null values
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#cheking unique values-our target variable have only 2 unique values its clasification problem
df.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %%
#checking if there is any space,nan values
df.isin(['-',' ','NA']).sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#Now checking how many ? present in data- no question mark seen may be there is space lets try it
#df.isin([' ?']).sum()
df.isin(['?']).sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#there are ? with space before it now we replace ? with NAN values
df.isin([' ?']).sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %%
#replacing ? with NAN values
df=df.replace(' ?',np.nan)

# %%
#All question marked remove 
df.isin([' ?']).sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#cheking duplicate rows in data
df.duplicated().sum()
# Out:
# 24

# %%
# we will remove duplicate values 
#df.drop_duplicates(keep='last', inplace=True)
df=df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (32536, 15)

# %%
#now cheking percentage of null values
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                 Missing Values  % Missing data
# Occupation                1843        5.664495
# Workclass                 1836        5.642980
# Native_country             582        1.788788
# Age                          0        0.000000
# Fnlwgt                       0        0.000000
# Education                    0        0.000000
# Education_num                0        0.000000
# Marital_status               0        0.000000
# Relationship                 0        0.000000
# Race                         0        0.000000
# Sex                          0        0.000000
# Capital_gain                 0        0.000000
# Capital_loss                 0        0.000000
# Hours_per_week               0        0.000000
# Income                       0        0.000000

# %%
#cheking missing values by heat map--there are missing values in data work place,occupation and native country(we have replace ? with nan )
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#cheking data format 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32536 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32536 non-null  int64
#  1   Workclass       30700 non-null  object
#  2   Fnlwgt          32536 non-null  int64
#  3   Education       32536 non-null  object
#  4   Education_num   32536 non-null  int64
#  5   Marital_status  32536 non-null  object
#  6   Occupation      30693 non-null  object
#  7   Relationship    32536 non-null  object
#  8   Race            32536 non-null  object
#  9   Sex             32536 non-null  object
#  10  Capital_gain    32536 non-null  int64
#  11  Capital_loss    32536 non-null  int64
#  12  Hours_per_week  32536 non-null  int64
#  13  Native_country  31954 non-null  object
#  14  Income          32536 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %% [markdown]
# # int 64 are all  integer and rest are numerical coluns now we deal with missing values
# #all missing values are in categorical column so we replace all by mode

# %%
#cheking mode for for 3 columns
print(df['Occupation'].mode())
print(df['Workclass'].mode())
print(df['Native_country'].mode())
# Out:
# 0     Prof-specialty
# Name: Occupation, dtype: object
# 0     Private
# Name: Workclass, dtype: object
# 0     United-States
# Name: Native_country, dtype: object

# %%
#replacing null values with mode 
df['Occupation'].fillna(df['Occupation'].mode()[0],inplace=True)
df['Workclass'].fillna(df['Workclass'].mode()[0],inplace=True)
df['Native_country'].fillna(df['Native_country'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# #now going towars statistical and visualization of data

# %%
#checking statistical hignlites of data--outliers are present in data along with 0 values
dis=df.describe()
dis
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32536.000000  3.253600e+04   32536.000000  32536.000000  32536.000000
# mean      38.585536  1.897843e+05      10.081725   1078.410069     87.370912
# std       13.638193  1.055563e+05       2.571622   7388.068465    403.107737
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369932e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32536.000000
# mean        40.440343
# std         12.347079
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#creating deat map for describe
plt.figure(figsize=(20,15))
sns.heatmap(dis,linewidths=.1,fmt='.1g',linecolor='black',annot=True,cmap='Blues_r')
plt.yticks(rotation=0);
plt.show()

# %%
#Segregating categorical and numerical columns 
#checking for categorical columns
categirical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categirical_col.append(i)
print('catgdata',categirical_col)
print('\n')
# Out:
# catgdata ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
#for checking numerical data
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print('numerical',numerical_col)
print('\n')
# Out:
# numerical ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']

# %%
for i in categirical_col:
    print(i)
    print(df[i].value_counts())
    print('='*100)
# Out:
# Workclass
#  Private             24509
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# ...
# Education
#  HS-grad         10494
#  Some-college     7282
#  Bachelors        5352
#  Masters          1722
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           645
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           332
#  1st-4th           166
#  Preschool          50
# Name: Education, dtype: int64
# ...
# Marital_status
#  Married-civ-spouse       14970
#  Never-married            10666
#  Divorced                  4441
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# ...

# %%
#univariate Analysis= to draw graph with one column only
ax=sns.countplot(data=df,x='Income')
print(df['Income'].value_counts())
# Out:
#  <=50K    24697
#  >50K      7839
# Name: Income, dtype: int64

# %%
sns.catplot(x='Age',col='Income',palette='ocean' ,kind='count', data=df)

# %%
sns.catplot(x='Workclass',col='Income',palette='ocean' ,kind='count', data=df)

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
sns.catplot(x='Education',col='Income',palette='ocean' ,kind='count', data=df)

# %%
sns.catplot(x='Marital_status',col='Income',palette='ocean' ,kind='count', data=df)

# %%
sns.catplot(x='Occupation',col='Income',palette='ocean' ,kind='count', data=df)

# %%
sns.catplot(x='Relationship',col='Income',palette='ocean' ,kind='count', data=df)

# %%
sns.catplot(x='Sex',col='Income',palette='ocean' ,kind='count', data=df)

# %%
sns.catplot(x='Capital_gain',col='Income',palette='ocean' ,kind='count', data=df)

# %%
sns.catplot(x='Capital_loss',col='Income',palette='ocean' ,kind='count', data=df)

# %%
sns.catplot(x='Hours_per_week',col='Income',palette='ocean' ,kind='count', data=df)

# %%
sns.catplot(x='Fnlwgt',col='Income',palette='ocean' ,kind='count', data=df)

# %%
pd.crosstab(df['Income'],df["Workclass"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_ce03d_row0_col0 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_ce03d_row0_col1 {
#   background-color: #6bb566;
#   color: #f1f1f1;
# }
# #T_ce03d_row0_col2, #T_ce03d_row0_col7, #T_ce03d_row2_col0, #T_ce03d_row2_col1, #T_ce03d_row2_col2, #T_ce03d_row2_col3, #T_ce03d_row2_col4, #T_ce03d_row2_col5, #T_ce03d_row2_col6, #T_ce03d_row2_col7, #T_ce03d_row2_col8 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_ce03d_row0_col3 {
#   background-color: #44a266;
#   color: #f1f1f1;
# }
# #T_ce03d_row0_col4, #T_ce03d_row1_col0, #T_ce03d_row1_col1, #T_ce03d_row1_col2, #T_ce03d_row1_col3, #T_ce03d_row1_col5, #T_ce03d_row1_col6, #T_ce03d_row1_col7, #T_ce03d_row1_col8 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ce03d_row0_col5 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_ce03d_row0_col6 {
#   background-color: #5faf66;
#   color: #f1f1f1;
# }
# #T_ce03d_row0_col8 {
#   background-color: #51a866;
# ...

# %%
# in above data we see the income in various  work class distribution highest 50+ income is from private

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
df['Education'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontsize':13}, shadow=True)
plt.title('Graph education', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
pd.crosstab(df['Education'],df["Workclass"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_58652_row0_col0, #T_58652_row2_col0, #T_58652_row2_col1, #T_58652_row2_col4, #T_58652_row2_col5, #T_58652_row2_col6, #T_58652_row3_col3, #T_58652_row3_col5, #T_58652_row4_col5, #T_58652_row5_col6, #T_58652_row10_col3 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_58652_row0_col1, #T_58652_row1_col1, #T_58652_row1_col4, #T_58652_row2_col3, #T_58652_row2_col8, #T_58652_row5_col4, #T_58652_row6_col5, #T_58652_row6_col8, #T_58652_row14_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_58652_row0_col2, #T_58652_row15_col2 {
#   background-color: #b6db66;
#   color: #000000;
# }
# #T_58652_row0_col3, #T_58652_row7_col3, #T_58652_row7_col5, #T_58652_row7_col6, #T_58652_row14_col0 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_58652_row0_col4, #T_58652_row5_col3, #T_58652_row5_col8, #T_58652_row6_col3, #T_58652_row10_col0, #T_58652_row14_col8 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# ...

# %%
# income V/S education
sns.set_palette
table = pd.crosstab(df['Education'], df['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,7))
plt.title('Percent Income distribution as per Education', fontsize=22, fontweight='bold')
plt.xlabel('Education', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %%
pd.crosstab(df['Occupation'],[df.Sex,df.Income], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style type="text/css">
# #T_66d00_row0_col0 {
#   background-color: #00c19e;
#   color: #f1f1f1;
# }
# #T_66d00_row0_col1, #T_66d00_row7_col0, #T_66d00_row9_col4 {
#   background-color: #00d196;
#   color: #000000;
# }
# #T_66d00_row0_col2, #T_66d00_row6_col4 {
#   background-color: #00f087;
#   color: #000000;
# }
# #T_66d00_row0_col3, #T_66d00_row7_col1, #T_66d00_row13_col3 {
#   background-color: #00f485;
#   color: #000000;
# }
# #T_66d00_row0_col4 {
#   background-color: #00e28e;
#   color: #000000;
# }
# #T_66d00_row1_col0, #T_66d00_row1_col1, #T_66d00_row1_col2, #T_66d00_row1_col3, #T_66d00_row1_col4, #T_66d00_row4_col1, #T_66d00_row5_col1, #T_66d00_row8_col1, #T_66d00_row8_col2, #T_66d00_row8_col3 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_66d00_row2_col0, #T_66d00_row10_col4, #T_66d00_row12_col2 {
#   background-color: #00fa82;
#   color: #000000;
# }
# #T_66d00_row2_col1, #T_66d00_row4_col3, #T_66d00_row5_col0, #T_66d00_row6_col1 {
# ...

# %%
#multi data analysis using pair plot
sns.pairplot(df,hue="Income",palette="Dark2")

# %%
#now we move towars encoding categorical data to numerical data
#encoding categorical column using odinal encoder 
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        5.0   83311        9.0             13             2.0
# 1       38        3.0  215646       11.0              9             0.0
# 2       53        3.0  234721        1.0              7             2.0
# 3       28        3.0  338409        9.0             13             2.0
# 4       37        3.0  284582       12.0             14             2.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        3.0  257302        7.0             12             2.0
# 32556   40        3.0  154374       11.0              9             2.0
# 32557   58        3.0  151910       11.0              9             6.0
# 32558   22        3.0  201490       11.0              9             4.0
# 32559   52        4.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
#cheking out liers by box plot
plt.figure(figsize=(15,8),facecolor='white')
plotnumber=1
for col in numerical_col:
    if plotnumber<=20:
        ax=plt.subplot(5,2,plotnumber)
        sns.boxplot(df[col],palette= 'Set2_r')
        plt.xlabel(col , fontsize=15)
        plt.yticks(rotation=0 , fontsize=10)
    plotnumber+=1 
plt.tight_layout()

# %%
#Dropping unnecessory columns
df.drop(["Fnlwgt", "Education"], axis=1, inplace=True)

# %%
from scipy.stats import zscore
out_features=df[['Age', 'Workclass', 'Education_num', 'Marital_status', 'Occupation','Relationship', 'Race', 'Sex', 'Capital_gain', 'Capital_loss','Hours_per_week', 'Native_country']]
z=np.abs(zscore(out_features))
z
# Out:
#             Age  Workclass  Education_num  Marital_status  Occupation  \
# 0      0.836961   1.720777       1.134817        0.405890    0.790197
# 1      0.042934   0.085203       0.420646        1.733664    0.286803
# 2      1.056935   0.085203       1.198377        0.405890    0.286803
# 3      0.776180   0.085203       1.134817        0.405890    0.719986
# 4      0.116259   0.085203       1.523683        0.405890    0.790197
# ...         ...        ...            ...             ...         ...
# 32555  0.849505   0.085203       0.745951        0.405890    1.475078
# 32556  0.103715   0.085203       0.420646        0.405890    0.035106
# 32557  1.423558   0.085203       0.420646        2.249657    1.545289
# 32558  1.216128   0.085203       0.420646        0.921884    1.545289
# 32559  0.983611   0.817787       0.420646        0.405890    0.790197
#
#        Relationship      Race       Sex  Capital_gain  Capital_loss  \
# ...

# %%
df=df[(z<3).all(axis=1)]

df.shape
# Out:
# (28061, 13)

# %%
# cheking Skewness
df.skew()
# Out:
# Age                0.487918
# Workclass          0.080746
# Education_num     -0.147601
# Marital_status    -0.046623
# Occupation         0.015247
# Relationship       0.752334
# Race              -2.549199
# Sex               -0.689977
# Capital_gain       4.924729
# Capital_loss      29.669292
# Hours_per_week    -0.359365
# Native_country    -5.348195
# Income             1.322011
# dtype: float64

# %%
numerical=['Age','Capital_gain', 'Capital_loss', 'Hours_per_week']

# %%
#Graphical representation of skewness
#now checking how data have been distributed in remaining column
plt.figure(figsize=(10, 6),facecolor='white')
plotnumber=1
for col in numerical:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
#skewness in capital loss and profit there are multiple 0 we will deal it later

# %%
df.corr()
# Out:
#                      Age  Workclass  Education_num  Marital_status  \
# Age             1.000000   0.029674       0.045622       -0.286328
# Workclass       0.029674   1.000000      -0.002200       -0.015623
# Education_num   0.045622  -0.002200       1.000000       -0.058587
# Marital_status -0.286328  -0.015623      -0.058587        1.000000
# Occupation     -0.001610   0.008779       0.073142        0.036477
# Relationship   -0.270591  -0.057823      -0.092447        0.183248
# Race            0.021292   0.067532       0.080766       -0.084558
# Sex             0.089469   0.069617       0.003688       -0.125361
# Capital_gain    0.131998   0.011083       0.157858       -0.069601
# Capital_loss    0.023459  -0.010613       0.007348       -0.016396
# Hours_per_week  0.090783   0.028104       0.156303       -0.196053
# Native_country  0.037494   0.001938       0.149688       -0.032575
# Income          0.241844  -0.007699       0.320271       -0.194146
#
# ...

# %%
#visualising co-relation 
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(),annot=True,fmt='.2f',linewidth=.2,linecolor='Black',cmap='Spectral')
plt.xlabel('figure',fontsize=14)
plt.ylabel('feature_name',fontsize=14)
plt.title('Descriptive graph',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(22,7))
df.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('corelation between label and feature using barplot',fontsize=20)
plt.show()

# %%
#Cheking multicoloniarity 
#finding varience inflation factor in each scaled columni.e x shape[1/1-r2))

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(df.values,i) for i in range (len(df.columns))]
vif['Features']=df.columns

vif
# Out:
#     VIF Values        Features
# 0    10.452897             Age
# 1     8.807425       Workclass
# 2    21.287850   Education_num
# 3     4.358505  Marital_status
# 4     3.357557      Occupation
# 5     2.937270    Relationship
# 6    36.291318            Race
# 7     4.566872             Sex
# 8     1.209589    Capital_gain
# 9     1.004295    Capital_loss
# 10   15.202917  Hours_per_week
# 11   79.077624  Native_country
# 12    1.777448          Income

# %%
# Segregating target variable and input 
x = df.drop(['Income'], axis =1)
y = df['Income']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#             Age  Workclass  Education_num  Marital_status  Occupation  \
# 0      0.887585   1.740845       1.213143       -0.404984   -0.776014
# 1     -0.009172  -0.075945      -0.439241       -1.721815   -0.275785
# 2      1.111775  -0.075945      -1.265433       -0.404984   -0.275785
# 3     -0.083902  -0.075945       1.626239       -0.404984   -0.776014
# 4      0.812856  -0.075945      -2.091625        0.253432    0.224445
# ...         ...        ...            ...             ...         ...
# 28056 -0.831199  -0.075945       0.800047       -0.404984    1.475018
# 28057  0.140288  -0.075945      -0.439241       -0.404984   -0.025670
# 28058  1.485423  -0.075945      -0.439241        2.228679   -1.526358
# 28059 -1.204848  -0.075945      -0.439241        0.911847   -1.526358
# 28060  1.037045   0.832450      -0.439241       -0.404984   -0.776014
#
#        Relationship      Race      Sex  Capital_gain  Capital_loss  \
# ...

# %%
#Balacing target variable 
! pip install imblearn
from imblearn . over_sampling import SMOTE
SM=SMOTE()
x1,y1=SM.fit_resample(x,y)
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\91903\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\91903\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\91903\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\91903\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\91903\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\91903\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\91903\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\91903\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\91903\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\91903\anaconda3\lib\site-packages)
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu=0
maxRS=0
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=.30,random_state=i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
    print('best accuracy',maxAccu,'at random_state',maxRS)
# Out:
# best accuracy 0.8863792971441696 at random_state 0
# best accuracy 0.889824668861496 at random_state 1
# best accuracy 0.889824668861496 at random_state 1
# best accuracy 0.889824668861496 at random_state 1
# best accuracy 0.8900543603093178 at random_state 4
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.8902840517571395 at random_state 5
# best accuracy 0.891126253732486 at random_state 15
# best accuracy 0.8931934767628819 at random_state 16
# best accuracy 0.8931934767628819 at random_state 16
# ...

# %%
# again we prep data for train and test to other also
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=.30,random_state=maxRS)
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
## Checking Accuracy for logistic Regression

LR=LogisticRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.7726820304723987
# [[4986 1511]
#  [1458 5106]]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.77      0.77      6497
#          1.0       0.77      0.78      0.77      6564
#
#     accuracy                           0.77     13061
#    macro avg       0.77      0.77      0.77     13061
# weighted avg       0.77      0.77      0.77     13061

# %%
# using AdaBoostingClassifier
ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC=ABC.predict(x_test)
print(accuracy_score(y_test,predABC))
print(confusion_matrix(y_test,predABC))
print(classification_report(y_test,predABC))
# Out:
# 0.8499349207564505
# [[5302 1195]
#  [ 765 5799]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.82      0.84      6497
#          1.0       0.83      0.88      0.86      6564
#
#     accuracy                           0.85     13061
#    macro avg       0.85      0.85      0.85     13061
# weighted avg       0.85      0.85      0.85     13061

# %%
#now checking accuracy for ExtraTree Classifier
ET=ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET=ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.8954138274251588
# [[5757  740]
#  [ 626 5938]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.89      0.89      6497
#          1.0       0.89      0.90      0.90      6564
#
#     accuracy                           0.90     13061
#    macro avg       0.90      0.90      0.90     13061
# weighted avg       0.90      0.90      0.90     13061

# %%
from sklearn.neighbors import KNeighborsClassifier
#now checking accuracy for KNN
KNN=KNeighborsClassifier()
KNN.fit(x_train,y_train)
predKNN=KNN.predict(x_test)
print(accuracy_score(y_test,predKNN))
print(confusion_matrix(y_test,predKNN))
print(classification_report(y_test,predKNN))
# Out:
# 0.8588163234055586
# [[5162 1335]
#  [ 509 6055]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.79      0.85      6497
#          1.0       0.82      0.92      0.87      6564
#
#     accuracy                           0.86     13061
#    macro avg       0.86      0.86      0.86     13061
# weighted avg       0.86      0.86      0.86     13061

# %%
#now we have to cross check our Algo by methos called Cross Validation score from sklearn.mod
from sklearn.model_selection import cross_val_score

# %%
#checking CV score for Logistic Regression
score=cross_val_score(LR,x1,y1)
print(score)
print(score.mean())
print('difference between accuracy score and crossvalidation score is -',accuracy_score(y_test,predLR)-score.mean())
# Out:
# [0.7586999  0.76972551 0.76180085 0.76628    0.7705031 ]
# 0.7654018721282029
# difference between accuracy score and crossvalidation score is - 0.0072801583441958195

# %%
#checking CV score for ADA Boost Model
score=cross_val_score(ABC,x1,y1)
print(score)
print(score.mean())
print('difference between accuracy score and crossvalidation score is -',accuracy_score(y_test,predABC)-score.mean())
# Out:
# [0.81635466 0.84311474 0.8531067  0.86149075 0.85561682]
# 0.8459367317518316
# difference between accuracy score and crossvalidation score is - 0.003998189004618902

# %%
#checking CV score for Extra tree classifier
score=cross_val_score(ET,x1,y1)
print(score)
print(score.mean())
print('difference between accuracy score and crossvalidation score is -',accuracy_score(y_test,predET)-score.mean())
# Out:
# [0.84621569 0.88227863 0.91386241 0.92236132 0.92212267]
# 0.8973681433943728
# difference between accuracy score and crossvalidation score is - -0.0019543159692139156

# %%
#checking CV score for KNN
score=cross_val_score(KNN,x1,y1)
print(score)
print(score.mean())
print('difference between accuracy score and crossvalidation score is -',accuracy_score(y_test,predKNN)-score.mean())
# Out:
# [0.84035833 0.8524176  0.85988285 0.86459171 0.86204916]
# 0.855859929922166
# difference between accuracy score and crossvalidation score is - 0.0029563934833926053

# %%
#Extra tree classifyer have highest accuracy and minimum differnce hence now we do hyper parameter tunning
from sklearn.model_selection import GridSearchCV

parameter={'criterion':['gini','entropy'],'random_state':[10,50,1000],'max_depth':[0,10,20],'n_jobs':[-2,-1,1],'n_estimators':[50,100,200,300]}

# %%
GCV=GridSearchCV(ExtraTreesClassifier(),parameter ,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [50, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1000]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'n_estimators': 50,
#  'n_jobs': -2,
#  'random_state': 1000}

# %%
final_model=ExtraTreesClassifier(criterion='gini',max_depth=20,n_estimators=50,n_jobs=-2,random_state=1000)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 87.05305872444683

# %%
from sklearn import metrics
fpr,tpr,thresholds=metrics.roc_curve(y_test,pred)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=final_model)
display.plot()

# %%
import joblib
import pickle
filename='Census_Income prediction model.pkl'
